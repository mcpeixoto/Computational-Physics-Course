# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import sqrt, sin, exp
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from copy import copy
from numpy import sin, cos, pi
import random
from numpy import loadtxt
# %matplotlib inline

# %% [markdown]
# ## Ex 1

# %%
data = loadtxt("folha7-data1.txt")

# %%
plt.figure(figsize=(8,4))
plt.plot(data[:,1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [38], in <module>
#       1 plt.figure(figsize=(8,4))
# ----> 2 plt.plot(data[:,1])
#       3 plt.show()
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
def DFT(k, x):
    N = len(x)
    return sum(x[n]*exp(-2j*pi*k*n/N) for n in range(N))


# The DFT of the signal
def DFT_signal(x):
    N = len(x)
    return np.array([DFT(k, x) for k in range(N//2+1)]) # se nao meter //2+1 tou a dar plot a dados simétricos

# %%
X = DFT_signal(data[:, 1])
plt.figure(figsize=(8,4))
plt.plot(X)
plt.show()
# Out:
# C:\Users\migue\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
X = np.fft.rfft(data[:, 1])
plt.figure(figsize=(8,4))
plt.plot(X)
plt.show()
# Out:
# C:\Users\migue\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# ## Ex 2

# %% [markdown]
# import talib as ta
# data = loadtxt("folha7-data2.txt")
# plt.figure(figsize=(10,5))
# plt.plot(data)
# plt.show()

# %%
data = loadtxt("folha7-data2.txt")
data.shape
# Out:
# (1024,)

# %%
plt.figure(figsize=(10,5))
plt.plot(data, label='Original')

rfft_array = np.fft.rfft(data)
rfft_array[int(rfft_array.shape[0]*0.1):] = 0 # Colocar 90% dos pontos a 0
data_reconstructed = np.fft.irfft(rfft_array)
plt.plot(data_reconstructed, label='10%')

rfft_array = np.fft.rfft(data)
rfft_array[int(rfft_array.shape[0]*0.02):] = 0 # Colocar 98% dos pontos a 0
data_reconstructed = np.fft.irfft(rfft_array)
plt.plot(data_reconstructed, label='2%')

#plt.plot(ta.SMA(data, 20), label="SMA 20 points")
#plt.plot(ta.SMA(data, 150), label="SMA 150 points")
plt.legend()
plt.show()

# %% [markdown]
# ## Ex 3

# %%
data = loadtxt("folha7-data3.txt")
plt.figure(figsize=(10,5))
plt.plot(data[:, 0], data[:, 1])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(data[:, 1][100:400])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(np.fft.rfft(data[:, 1])[:50])
plt.show()
# Out:
# C:\Users\migue\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.figure(figsize=(10,5))
plt.plot((abs(np.fft.rfft(data[:, 1]))**2)[1:200])
plt.show()

# %% [markdown]
# O eixo dos x's está em K
#
# o K que queremos é +/- 24 logo N/k será a frequencia

# %%
len(data[:,1]) / 24
# Out:
# 130.95833333333334

# %% [markdown]
# ## Ex 4

# %%
data4 = loadtxt("folha7-data4.txt")
plt.figure(figsize=(10,5))
plt.plot(data4)
plt.show()

# %%
data5 = loadtxt("folha7-data5.txt")
plt.figure(figsize=(10,5))
plt.plot(data5)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(np.fft.rfft(data4))
plt.show()
# Out:
# C:\Users\migue\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.figure(figsize=(10,5))
plt.plot(np.fft.rfft(data5))
plt.show()
# Out:
# C:\Users\migue\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
